# %%
import pandas as pd

# %%
def cargar_y_verificar_datos(ruta_archivo):
    # Cargar el archivo CSV en un DataFrame
    df = pd.read_csv(ruta_archivo)
    
    # Mostrar las primeras filas del DataFrame para verificar la carga correcta
    print(f"Primeras filas del archivo {ruta_archivo}:")
    print(df.head())
    
    # Verificar si hay valores nulos
    print(f"\nValores nulos por columna en {ruta_archivo}:")
    print(df.isnull().sum())
    
    # Verificar tipos de datos
    print(f"\nTipos de datos en {ruta_archivo}:")
    print(df.dtypes)
    
    return df

def revisar_proporcion_nulos(df):
    total_valores = df.size
    total_nulos = df.isnull().sum().sum()
    proporcion_nulos = total_nulos / total_valores
    return proporcion_nulos

# Listado de archivos CSV y sus rutas
archivos_csv = {
    "df_precio_hotelero": 'larioja.org/Turismo/Precios turísticos/Índice de precios e indicadores de rentabilidad del sector hotelero de La Rioja/1-indice general y desglose por categorías y meses 20603001.csv',
    "df_adr_revpar": 'larioja.org/Turismo/Precios turísticos/Índice de precios e indicadores de rentabilidad del sector hotelero de La Rioja/2-Adr y RevPar de puntos turísticos por categorías, municipio y meses 20603002.csv',
    "df_ipac": 'larioja.org/Turismo/Precios turísticos/Índices de precios de establecimientos extrahoteleros de La Rioja/Consultas generales/1-Índice de precios de campings (IPAC) desglosado por meses.csv',
    "df_ipap": 'larioja.org/Turismo/Precios turísticos/Índices de precios de establecimientos extrahoteleros de La Rioja/Consultas generales/2-Índice de precios de apartamentos (IPAP) desglosado por tarifa y meses.csv',
    "df_iptr": 'larioja.org/Turismo/Precios turísticos/Índices de precios de establecimientos extrahoteleros de La Rioja/Consultas generales/3-Índice de precios de turismo rural (IPTR) desglosado por tarifa y meses.csv',
    "df_num_empresas": 'larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Número de empresas del sector turístico/1-Número de empresas y locales en el sector turístico.csv',
    "df_afiliados_regimen": 'larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Afiliados a la Seguridad Social del sector turístico/1-Afiliados a la seguridad social en el sector turístico por régimen.csv',
    "df_afiliados_contrato": 'larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Afiliados a la Seguridad Social del sector turístico/2-Afiliados a la seguridad social en el sector turístico por tipo de contrato.csv',
    "df_magnitudes_2015": 'larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (año 2015 y siguientes)/1-Principales magnitudes en el sector turístico.csv',
    "df_indicadores_2015": 'larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (año 2015 y siguientes)/2-Principales indicadores en el sector turístico.csv',
    "df_personal_2015": 'larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (año 2015 y siguientes)/3-Personal ocupado en el sector turístico.csv',
    "df_magnitudes_2008_2014": 'larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (serie 2008 - 2014)/1-Principales magnitudes en el sector turístico.csv',
    "df_indicadores_2008_2014": 'larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (serie 2008 - 2014)/2-Principales indicadores en el sector turístico.csv',
    "df_personal_2008_2014": 'larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (serie 2008 - 2014)/3-Personal ocupado en el sector turístico.csv',
    "df_establecimientos_turisticos": 'larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/1-Establecimientos turísticos y capacidad por municipios y tipo de establecimiento.csv',
    "df_hoteles_capacidad": 'larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/2-Número de hoteles y capacidad por municipios y categoría.csv',
    "df_apartamentos_capacidad": 'larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/5-Número de apartamentos y capacidad por municipios y categoría.csv',
    "df_viviendas_uso_turistico": 'larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/6-Número de viviendas de uso turístico por municipios.csv',
    "df_campings_capacidad": 'larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/7-Número de campings y capacidad por municipios y categoría.csv',
    "df_casas_rurales_capacidad": 'larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/8-Número de casas rurales y capacidad por municipios y categoría.csv',
    "df_plazas_por_habitante": 'larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/10-Número de plazas de alojamiento por cada mil habitantes por municipios.csv',
    "df_gasto_via_acceso": 'larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/1-Gasto de los turistas internacionales según via de acceso principal.csv',
    "df_gasto_alojamiento": 'larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/2-Gasto de los turistas internacionales según alojamiento principal.csv',
    "df_gasto_motivo_viaje": 'larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/3-Gasto de los turistas internacionales según motivo principal del viaje.csv',
    "df_gasto_pais_residencia": 'larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/4-Gasto de los turistas internacionales según país de residencia.csv',
    "df_gasto_organizacion_viaje": 'larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/5-Gasto de los turistas internacionales según forma organización del viaje.csv',
    "df_gasto_duracion_viaje": 'larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/6-Gasto de los turistas internacionales según duración del viaje.csv',
    "df_gasto_partidas": 'larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/7-Gasto de los turistas internacionales según partidas de gasto.csv',
    "df_turistas_via_acceso": 'larioja.org/Turismo/Encuestas turísticas/Estadística de Movimientos Turísticos en Fronteras para La Rioja/1-Número de turistas según via de acceso principal.csv',
    "df_turistas_alojamiento": 'larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/2-Gasto de los turistas internacionales según alojamiento principal.csv',
    "df_turistas_motivo_viaje": 'larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/3-Gasto de los turistas internacionales según motivo principal del viaje.csv',
    "df_turistas_pais_residencia": 'larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/4-Gasto de los turistas internacionales según país de residencia.csv',
    "df_turistas_organizacion_viaje": 'larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/5-Gasto de los turistas internacionales según forma organización del viaje.csv',
    "df_turistas_duracion_viaje": 'larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/6-Gasto de los turistas internacionales según duración del viaje.csv'
}

# Cargar y verificar cada archivo CSV
dataframes = {}
for nombre_df, ruta in archivos_csv.items():
    print(f"\nCargando y verificando {nombre_df}...")
    dataframes[nombre_df] = cargar_y_verificar_datos(ruta)
    # Revisar la proporción de nulos
    proporcion_nulos = revisar_proporcion_nulos(dataframes[nombre_df])
    print(f"Proporción de nulos en {nombre_df}: {proporcion_nulos:.2%}")
# Out:
# Cargando y verificando df_precio_hotelero...
# Primeras filas del archivo larioja.org/Turismo/Precios turísticos/Índice de precios e indicadores de rentabilidad del sector hotelero de La Rioja/1-indice general y desglose por categorías y meses 20603001.csv:
#    Periodo                 Categoría   DATA
# 0  2016M01                     TOTAL  85.32
# 1  2016M01        4 estrellas de oro  90.27
# 2  2016M01        3 estrellas de oro  81.61
# 3  2016M01         1 estrella de oro  96.86
# 4  2016M01  2 y 3 estrellas de plata  66.79
#
# Valores nulos por columna en larioja.org/Turismo/Precios turísticos/Índice de precios e indicadores de rentabilidad del sector hotelero de La Rioja/1-indice general y desglose por categorías y meses 20603001.csv:
# Periodo       0
# Categoría     0
# DATA         44
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Precios turísticos/Índice de precios e indicadores de rentabilidad del sector hotelero de La Rioja/1-indice general y desglose por categorías y meses 20603001.csv:
# Periodo       object
# Categoría     object
# DATA         float64
# dtype: object
# Proporción de nulos en df_precio_hotelero: 2.21%
#
# Cargando y verificando df_adr_revpar...
# Primeras filas del archivo larioja.org/Turismo/Precios turísticos/Índice de precios e indicadores de rentabilidad del sector hotelero de La Rioja/2-Adr y RevPar de puntos turísticos por categorías, municipio y meses 20603002.csv:
#    Periodo Municipio                                          Indicador  \
# 0  2016M01  LA RIOJA  Facturación media por cada habitación ocupada ...
# 1  2016M01  LA RIOJA  Facturación media por cada habitación ocupada ...
# 2  2016M01  LA RIOJA  Facturación media por cada habitación ocupada ...
# 3  2016M01  LA RIOJA  Facturación media por cada habitación ocupada ...
# 4  2016M01  LA RIOJA  Facturación media por cada habitación ocupada ...
#
#               Categoría   DATA
# 0                 TOTAL  56.87
# 1    4 estrellas de oro  77.26
# 2    3 estrellas de oro  51.87
# 3    2 estrellas de oro  42.25
# 4  2 estrellas de plata  47.06
#
# Valores nulos por columna en larioja.org/Turismo/Precios turísticos/Índice de precios e indicadores de rentabilidad del sector hotelero de La Rioja/2-Adr y RevPar de puntos turísticos por categorías, municipio y meses 20603002.csv:
# Periodo         0
# Municipio       0
# Indicador       0
# Categoría       0
# DATA         4514
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Precios turísticos/Índice de precios e indicadores de rentabilidad del sector hotelero de La Rioja/2-Adr y RevPar de puntos turísticos por categorías, municipio y meses 20603002.csv:
# Periodo       object
# Municipio     object
# Indicador     object
# Categoría     object
# DATA         float64
# dtype: object
# Proporción de nulos en df_adr_revpar: 13.48%
#
# Cargando y verificando df_ipac...
# Primeras filas del archivo larioja.org/Turismo/Precios turísticos/Índices de precios de establecimientos extrahoteleros de La Rioja/Consultas generales/1-Índice de precios de campings (IPAC) desglosado por meses.csv:
#    Periodo       Variable    DATA
# 0  2016M01         Índice  217.98
# 1  2016M01  Var (%) anual    1.64
# 2  2016M02         Índice  207.84
# 3  2016M02  Var (%) anual   -1.40
# 4  2016M03         Índice  143.65
#
# Valores nulos por columna en larioja.org/Turismo/Precios turísticos/Índices de precios de establecimientos extrahoteleros de La Rioja/Consultas generales/1-Índice de precios de campings (IPAC) desglosado por meses.csv:
# Periodo     0
# Variable    0
# DATA        0
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Precios turísticos/Índices de precios de establecimientos extrahoteleros de La Rioja/Consultas generales/1-Índice de precios de campings (IPAC) desglosado por meses.csv:
# Periodo      object
# Variable     object
# DATA        float64
# dtype: object
# Proporción de nulos en df_ipac: 0.00%
#
# Cargando y verificando df_ipap...
# Primeras filas del archivo larioja.org/Turismo/Precios turísticos/Índices de precios de establecimientos extrahoteleros de La Rioja/Consultas generales/2-Índice de precios de apartamentos (IPAP) desglosado por tarifa y meses.csv:
#    Periodo         Tarifa       Variable    DATA
# 0  2016M01          TOTAL         Índice  123.81
# 1  2016M01          TOTAL  Var (%) anual    7.71
# 2  2016M01         Normal         Índice     NaN
# 3  2016M01         Normal  Var (%) anual     NaN
# 4  2016M01  Fin de semana         Índice     NaN
#
# Valores nulos por columna en larioja.org/Turismo/Precios turísticos/Índices de precios de establecimientos extrahoteleros de La Rioja/Consultas generales/2-Índice de precios de apartamentos (IPAP) desglosado por tarifa y meses.csv:
# Periodo      0
# Tarifa       0
# Variable     0
# DATA        52
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Precios turísticos/Índices de precios de establecimientos extrahoteleros de La Rioja/Consultas generales/2-Índice de precios de apartamentos (IPAP) desglosado por tarifa y meses.csv:
# Periodo      object
# Tarifa       object
# Variable     object
# DATA        float64
# dtype: object
# Proporción de nulos en df_ipap: 2.23%
#
# Cargando y verificando df_iptr...
# Primeras filas del archivo larioja.org/Turismo/Precios turísticos/Índices de precios de establecimientos extrahoteleros de La Rioja/Consultas generales/3-Índice de precios de turismo rural (IPTR) desglosado por tarifa y meses.csv:
#    Periodo         Tarifa       Variable    DATA
# 0  2016M01          TOTAL         Índice  150.89
# 1  2016M01          TOTAL  Var (%) anual    2.06
# 2  2016M01         Normal         Índice  147.67
# 3  2016M01         Normal  Var (%) anual    3.17
# 4  2016M01  Fin de semana         Índice  150.13
#
# Valores nulos por columna en larioja.org/Turismo/Precios turísticos/Índices de precios de establecimientos extrahoteleros de La Rioja/Consultas generales/3-Índice de precios de turismo rural (IPTR) desglosado por tarifa y meses.csv:
# Periodo     0
# Tarifa      0
# Variable    0
# DATA        0
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Precios turísticos/Índices de precios de establecimientos extrahoteleros de La Rioja/Consultas generales/3-Índice de precios de turismo rural (IPTR) desglosado por tarifa y meses.csv:
# Periodo      object
# Tarifa       object
# Variable     object
# DATA        float64
# dtype: object
# Proporción de nulos en df_iptr: 0.00%
#
# Cargando y verificando df_num_empresas...
# Primeras filas del archivo larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Número de empresas del sector turístico/1-Número de empresas y locales en el sector turístico.csv:
#   Grupo actividad sector turístico           Indicador  Periodo     DATA
# 0           TOTAL SECTOR SERVICIOS  Número de empresas     2008  16501.0
# 1           TOTAL SECTOR SERVICIOS  Número de empresas     2009  16522.0
# 2           TOTAL SECTOR SERVICIOS  Número de empresas     2010  16666.0
# 3           TOTAL SECTOR SERVICIOS  Número de empresas     2011  16614.0
# 4           TOTAL SECTOR SERVICIOS  Número de empresas     2012  16508.0
#
# Valores nulos por columna en larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Número de empresas del sector turístico/1-Número de empresas y locales en el sector turístico.csv:
# Grupo actividad sector turístico     0
# Indicador                            0
# Periodo                              0
# DATA                                14
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Número de empresas del sector turístico/1-Número de empresas y locales en el sector turístico.csv:
# Grupo actividad sector turístico     object
# Indicador                            object
# Periodo                               int64
# DATA                                float64
# dtype: object
# Proporción de nulos en df_num_empresas: 1.79%
#
# Cargando y verificando df_afiliados_regimen...
# Primeras filas del archivo larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Afiliados a la Seguridad Social del sector turístico/1-Afiliados a la seguridad social en el sector turístico por régimen.csv:
#   Grupo actividad sector turístico Régimen de afiliación Periodo     DATA
# 0           TOTAL SECTOR SERVICIOS                 TOTAL  2011T2  74739.0
# 1           TOTAL SECTOR SERVICIOS                 TOTAL  2011T3  74384.0
# 2           TOTAL SECTOR SERVICIOS                 TOTAL  2011T4  73681.0
# 3           TOTAL SECTOR SERVICIOS                 TOTAL  2012T1  73363.0
# 4           TOTAL SECTOR SERVICIOS                 TOTAL  2012T2  73885.0
#
# Valores nulos por columna en larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Afiliados a la Seguridad Social del sector turístico/1-Afiliados a la seguridad social en el sector turístico por régimen.csv:
# Grupo actividad sector turístico      0
# Régimen de afiliación                 0
# Periodo                               0
# DATA                                281
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Afiliados a la Seguridad Social del sector turístico/1-Afiliados a la seguridad social en el sector turístico por régimen.csv:
# Grupo actividad sector turístico     object
# Régimen de afiliación                object
# Periodo                              object
# DATA                                float64
# dtype: object
# Proporción de nulos en df_afiliados_regimen: 4.67%
#
# Cargando y verificando df_afiliados_contrato...
# Primeras filas del archivo larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Afiliados a la Seguridad Social del sector turístico/2-Afiliados a la seguridad social en el sector turístico por tipo de contrato.csv:
#   Grupo actividad sector turístico Tipo de contrato Periodo   DATA
# 0           TOTAL SECTOR SERVICIOS            TOTAL  2011T2  74739
# 1           TOTAL SECTOR SERVICIOS            TOTAL  2011T3  74384
# 2           TOTAL SECTOR SERVICIOS            TOTAL  2011T4  73681
# 3           TOTAL SECTOR SERVICIOS            TOTAL  2012T1  73363
# 4           TOTAL SECTOR SERVICIOS            TOTAL  2012T2  73885
#
# Valores nulos por columna en larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Afiliados a la Seguridad Social del sector turístico/2-Afiliados a la seguridad social en el sector turístico por tipo de contrato.csv:
# Grupo actividad sector turístico    0
# Tipo de contrato                    0
# Periodo                             0
# DATA                                0
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Afiliados a la Seguridad Social del sector turístico/2-Afiliados a la seguridad social en el sector turístico por tipo de contrato.csv:
# Grupo actividad sector turístico    object
# Tipo de contrato                    object
# Periodo                             object
# DATA                                 int64
# dtype: object
# Proporción de nulos en df_afiliados_contrato: 0.00%
#
# Cargando y verificando df_magnitudes_2015...
# Primeras filas del archivo larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (año 2015 y siguientes)/1-Principales magnitudes en el sector turístico.csv:
#   Grupo actividad sector turístico             Indicador  Periodo         DATA
# 0           TOTAL SECTOR SERVICIOS  Consumos Intermedios     2015   912114.465
# 1           TOTAL SECTOR SERVICIOS  Consumos Intermedios     2016   964596.809
# 2           TOTAL SECTOR SERVICIOS  Consumos Intermedios     2017   998496.867
# 3           TOTAL SECTOR SERVICIOS  Consumos Intermedios     2018  1088201.830
# 4           TOTAL SECTOR SERVICIOS  Consumos Intermedios     2019  1134462.299
#
# Valores nulos por columna en larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (año 2015 y siguientes)/1-Principales magnitudes en el sector turístico.csv:
# Grupo actividad sector turístico    0
# Indicador                           0
# Periodo                             0
# DATA                                0
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (año 2015 y siguientes)/1-Principales magnitudes en el sector turístico.csv:
# Grupo actividad sector turístico     object
# Indicador                            object
# Periodo                               int64
# DATA                                float64
# dtype: object
# Proporción de nulos en df_magnitudes_2015: 0.00%
#
# Cargando y verificando df_indicadores_2015...
# Primeras filas del archivo larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (año 2015 y siguientes)/2-Principales indicadores en el sector turístico.csv:
#   Grupo actividad sector turístico      Indicador  Periodo       DATA
# 0           TOTAL SECTOR SERVICIOS  Salario medio     2015  19892.923
# 1           TOTAL SECTOR SERVICIOS  Salario medio     2016  19070.827
# 2           TOTAL SECTOR SERVICIOS  Salario medio     2017  19229.551
# 3           TOTAL SECTOR SERVICIOS  Salario medio     2018  20211.762
# 4           TOTAL SECTOR SERVICIOS  Salario medio     2019  21067.722
#
# Valores nulos por columna en larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (año 2015 y siguientes)/2-Principales indicadores en el sector turístico.csv:
# Grupo actividad sector turístico    0
# Indicador                           0
# Periodo                             0
# DATA                                0
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (año 2015 y siguientes)/2-Principales indicadores en el sector turístico.csv:
# Grupo actividad sector turístico     object
# Indicador                            object
# Periodo                               int64
# DATA                                float64
# dtype: object
# Proporción de nulos en df_indicadores_2015: 0.00%
#
# Cargando y verificando df_personal_2015...
# Primeras filas del archivo larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (año 2015 y siguientes)/3-Personal ocupado en el sector turístico.csv:
#   Grupo actividad sector turístico               Indicador  Periodo       DATA
# 0           TOTAL SECTOR SERVICIOS  Personal no remunerado     2015  11672.532
# 1           TOTAL SECTOR SERVICIOS  Personal no remunerado     2016  13379.933
# 2           TOTAL SECTOR SERVICIOS  Personal no remunerado     2017  12161.933
# 3           TOTAL SECTOR SERVICIOS  Personal no remunerado     2018  11939.725
# 4           TOTAL SECTOR SERVICIOS  Personal no remunerado     2019  11646.349
#
# Valores nulos por columna en larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (año 2015 y siguientes)/3-Personal ocupado en el sector turístico.csv:
# Grupo actividad sector turístico    0
# Indicador                           0
# Periodo                             0
# DATA                                0
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (año 2015 y siguientes)/3-Personal ocupado en el sector turístico.csv:
# Grupo actividad sector turístico     object
# Indicador                            object
# Periodo                               int64
# DATA                                float64
# dtype: object
# Proporción de nulos en df_personal_2015: 0.00%
#
# Cargando y verificando df_magnitudes_2008_2014...
# Primeras filas del archivo larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (serie 2008 - 2014)/1-Principales magnitudes en el sector turístico.csv:
#   Grupo actividad sector turístico  \
# 0           TOTAL SECTOR SERVICIOS
# 1           TOTAL SECTOR SERVICIOS
# 2           TOTAL SECTOR SERVICIOS
# 3           TOTAL SECTOR SERVICIOS
# 4           TOTAL SECTOR SERVICIOS
#
#                                          Indicador  Periodo        DATA
# 0  Excedente bruto de explotación (miles de euros)     2008  721640.388
# 1  Excedente bruto de explotación (miles de euros)     2009  578728.125
# 2  Excedente bruto de explotación (miles de euros)     2010  612539.060
# 3  Excedente bruto de explotación (miles de euros)     2011  544651.389
# 4  Excedente bruto de explotación (miles de euros)     2012  467381.413
#
# Valores nulos por columna en larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (serie 2008 - 2014)/1-Principales magnitudes en el sector turístico.csv:
# Grupo actividad sector turístico    0
# Indicador                           0
# Periodo                             0
# DATA                                0
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (serie 2008 - 2014)/1-Principales magnitudes en el sector turístico.csv:
# Grupo actividad sector turístico     object
# Indicador                            object
# Periodo                               int64
# DATA                                float64
# dtype: object
# Proporción de nulos en df_magnitudes_2008_2014: 0.00%
#
# Cargando y verificando df_indicadores_2008_2014...
# Primeras filas del archivo larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (serie 2008 - 2014)/2-Principales indicadores en el sector turístico.csv:
#   Grupo actividad sector turístico           Indicador  Periodo        DATA
# 0           TOTAL SECTOR SERVICIOS  Sueldos y salarios     2008  675273.907
# 1           TOTAL SECTOR SERVICIOS  Sueldos y salarios     2009  618180.322
# 2           TOTAL SECTOR SERVICIOS  Sueldos y salarios     2010  615968.456
# 3           TOTAL SECTOR SERVICIOS  Sueldos y salarios     2011  631114.561
# 4           TOTAL SECTOR SERVICIOS  Sueldos y salarios     2012  608698.047
#
# Valores nulos por columna en larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (serie 2008 - 2014)/2-Principales indicadores en el sector turístico.csv:
# Grupo actividad sector turístico    0
# Indicador                           0
# Periodo                             0
# DATA                                0
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (serie 2008 - 2014)/2-Principales indicadores en el sector turístico.csv:
# Grupo actividad sector turístico     object
# Indicador                            object
# Periodo                               int64
# DATA                                float64
# dtype: object
# Proporción de nulos en df_indicadores_2008_2014: 0.00%
#
# Cargando y verificando df_personal_2008_2014...
# Primeras filas del archivo larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (serie 2008 - 2014)/3-Personal ocupado en el sector turístico.csv:
#   Grupo actividad sector turístico               Indicador  Periodo       DATA
# 0           TOTAL SECTOR SERVICIOS  Personal no remunerado     2008  12887.719
# 1           TOTAL SECTOR SERVICIOS  Personal no remunerado     2009  12694.030
# 2           TOTAL SECTOR SERVICIOS  Personal no remunerado     2010  12335.670
# 3           TOTAL SECTOR SERVICIOS  Personal no remunerado     2011  11788.248
# 4           TOTAL SECTOR SERVICIOS  Personal no remunerado     2012  12100.205
#
# Valores nulos por columna en larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (serie 2008 - 2014)/3-Personal ocupado en el sector turístico.csv:
# Grupo actividad sector turístico    0
# Indicador                           0
# Periodo                             0
# DATA                                0
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Indicadores económicos del sector turístico en La Rioja/Indicadores del sector turístico en La Rioja/Principales macromagnitudes económicas del sector turístico (serie 2008 - 2014)/3-Personal ocupado en el sector turístico.csv:
# Grupo actividad sector turístico     object
# Indicador                            object
# Periodo                               int64
# DATA                                float64
# dtype: object
# Proporción de nulos en df_personal_2008_2014: 0.00%
#
# Cargando y verificando df_establecimientos_turisticos...
# Primeras filas del archivo larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/1-Establecimientos turísticos y capacidad por municipios y tipo de establecimiento.csv:
#   Municipio Tipo de establecimiento         Indicador  Periodo  DATA
# 0  LA RIOJA                 Hoteles  Establecimientos     2009  63.0
# 1  LA RIOJA                 Hoteles  Establecimientos     2010  63.0
# 2  LA RIOJA                 Hoteles  Establecimientos     2011  63.0
# 3  LA RIOJA                 Hoteles  Establecimientos     2012  66.0
# 4  LA RIOJA                 Hoteles  Establecimientos     2013  70.0
#
# Valores nulos por columna en larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/1-Establecimientos turísticos y capacidad por municipios y tipo de establecimiento.csv:
# Municipio                      0
# Tipo de establecimiento        0
# Indicador                      0
# Periodo                        0
# DATA                       56424
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/1-Establecimientos turísticos y capacidad por municipios y tipo de establecimiento.csv:
# Municipio                   object
# Tipo de establecimiento     object
# Indicador                   object
# Periodo                      int64
# DATA                       float64
# dtype: object
# Proporción de nulos en df_establecimientos_turisticos: 16.79%
#
# Cargando y verificando df_hoteles_capacidad...
# Primeras filas del archivo larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/2-Número de hoteles y capacidad por municipios y categoría.csv:
#   Municipio Categoría turística Indicador  Periodo    DATA
# 0  LA RIOJA               TOTAL    Plazas     2009  4613.0
# 1  LA RIOJA               TOTAL    Plazas     2010  4583.0
# 2  LA RIOJA               TOTAL    Plazas     2011  4583.0
# 3  LA RIOJA               TOTAL    Plazas     2012  4706.0
# 4  LA RIOJA               TOTAL    Plazas     2013  4713.0
#
# Valores nulos por columna en larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/2-Número de hoteles y capacidad por municipios y categoría.csv:
# Municipio                  0
# Categoría turística        0
# Indicador                  0
# Periodo                    0
# DATA                   46245
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/2-Número de hoteles y capacidad por municipios y categoría.csv:
# Municipio               object
# Categoría turística     object
# Indicador               object
# Periodo                  int64
# DATA                   float64
# dtype: object
# Proporción de nulos en df_hoteles_capacidad: 18.35%
#
# Cargando y verificando df_apartamentos_capacidad...
# Primeras filas del archivo larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/5-Número de apartamentos y capacidad por municipios y categoría.csv:
#   Municipio Categoría turística         Indicador  Periodo  DATA
# 0  LA RIOJA               TOTAL  Establecimientos     2009  37.0
# 1  LA RIOJA               TOTAL  Establecimientos     2010  44.0
# 2  LA RIOJA               TOTAL  Establecimientos     2011  44.0
# 3  LA RIOJA               TOTAL  Establecimientos     2012  50.0
# 4  LA RIOJA               TOTAL  Establecimientos     2013  62.0
#
# Valores nulos por columna en larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/5-Número de apartamentos y capacidad por municipios y categoría.csv:
# Municipio                  0
# Categoría turística        0
# Indicador                  0
# Periodo                    0
# DATA                   29895
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/5-Número de apartamentos y capacidad por municipios y categoría.csv:
# Municipio               object
# Categoría turística     object
# Indicador               object
# Periodo                  int64
# DATA                   float64
# dtype: object
# Proporción de nulos en df_apartamentos_capacidad: 17.79%
#
# Cargando y verificando df_viviendas_uso_turistico...
# Primeras filas del archivo larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/6-Número de viviendas de uso turístico por municipios.csv:
#   Municipio     Tipo de establecimiento  Periodo    DATA
# 0  LA RIOJA  Viviendas de uso turístico     2018   480.0
# 1  LA RIOJA  Viviendas de uso turístico     2019   796.0
# 2  LA RIOJA  Viviendas de uso turístico     2020  1042.0
# 3  LA RIOJA  Viviendas de uso turístico     2021  1072.0
# 4  LA RIOJA  Viviendas de uso turístico     2022  1094.0
#
# Valores nulos por columna en larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/6-Número de viviendas de uso turístico por municipios.csv:
# Municipio                    0
# Tipo de establecimiento      0
# Periodo                      0
# DATA                       566
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/6-Número de viviendas de uso turístico por municipios.csv:
# Municipio                   object
# Tipo de establecimiento     object
# Periodo                      int64
# DATA                       float64
# dtype: object
# Proporción de nulos en df_viviendas_uso_turistico: 11.55%
#
# Cargando y verificando df_campings_capacidad...
# Primeras filas del archivo larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/7-Número de campings y capacidad por municipios y categoría.csv:
#   Municipio Categoría turística Indicador  Periodo    DATA
# 0  LA RIOJA               TOTAL    Plazas     2009  6252.0
# 1  LA RIOJA               TOTAL    Plazas     2010  6252.0
# 2  LA RIOJA               TOTAL    Plazas     2011  6252.0
# 3  LA RIOJA               TOTAL    Plazas     2012  6252.0
# 4  LA RIOJA               TOTAL    Plazas     2013  6252.0
#
# Valores nulos por columna en larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/7-Número de campings y capacidad por municipios y categoría.csv:
# Municipio                  0
# Categoría turística        0
# Indicador                  0
# Periodo                    0
# DATA                   25614
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/7-Número de campings y capacidad por municipios y categoría.csv:
# Municipio               object
# Categoría turística     object
# Indicador               object
# Periodo                  int64
# DATA                   float64
# dtype: object
# Proporción de nulos en df_campings_capacidad: 19.52%
#
# Cargando y verificando df_casas_rurales_capacidad...
# Primeras filas del archivo larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/8-Número de casas rurales y capacidad por municipios y categoría.csv:
#   Municipio Categoría turística         Indicador  Periodo   DATA
# 0  LA RIOJA               TOTAL  Establecimientos     2009  107.0
# 1  LA RIOJA               TOTAL  Establecimientos     2010  112.0
# 2  LA RIOJA               TOTAL  Establecimientos     2011  112.0
# 3  LA RIOJA               TOTAL  Establecimientos     2012  124.0
# 4  LA RIOJA               TOTAL  Establecimientos     2013  130.0
#
# Valores nulos por columna en larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/8-Número de casas rurales y capacidad por municipios y categoría.csv:
# Municipio                  0
# Categoría turística        0
# Indicador                  0
# Periodo                    0
# DATA                   25857
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/8-Número de casas rurales y capacidad por municipios y categoría.csv:
# Municipio               object
# Categoría turística     object
# Indicador               object
# Periodo                  int64
# DATA                   float64
# dtype: object
# Proporción de nulos en df_casas_rurales_capacidad: 15.39%
#
# Cargando y verificando df_plazas_por_habitante...
# Primeras filas del archivo larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/10-Número de plazas de alojamiento por cada mil habitantes por municipios.csv:
#   Municipio       Indicador  Periodo     DATA
# 0  LA RIOJA  Plazas Totales     2009  14491.0
# 1  LA RIOJA  Plazas Totales     2010  14686.0
# 2  LA RIOJA  Plazas Totales     2011  14686.0
# 3  LA RIOJA  Plazas Totales     2012  15075.0
# 4  LA RIOJA  Plazas Totales     2013  15337.0
#
# Valores nulos por columna en larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/10-Número de plazas de alojamiento por cada mil habitantes por municipios.csv:
# Municipio       0
# Indicador       0
# Periodo         0
# DATA         2365
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Directorio de establecimientos turísticos/Directorio de alojamientos turísticos y plazas/Servicios de alojamiento/10-Número de plazas de alojamiento por cada mil habitantes por municipios.csv:
# Municipio     object
# Indicador     object
# Periodo        int64
# DATA         float64
# dtype: object
# Proporción de nulos en df_plazas_por_habitante: 10.56%
#
# Cargando y verificando df_gasto_via_acceso...
# Primeras filas del archivo larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/1-Gasto de los turistas internacionales según via de acceso principal.csv:
#   Via de acceso    Indicador  Periodo       DATA
# 0         TOTAL  Gasto total     2016   93087.88
# 1         TOTAL  Gasto total     2017  101962.17
# 2         TOTAL  Gasto total     2018  101126.50
# 3         TOTAL  Gasto total     2019   98201.73
# 4         TOTAL  Gasto total     2020   21835.28
#
# Valores nulos por columna en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/1-Gasto de los turistas internacionales según via de acceso principal.csv:
# Via de acceso    0
# Indicador        0
# Periodo          0
# DATA             0
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/1-Gasto de los turistas internacionales según via de acceso principal.csv:
# Via de acceso     object
# Indicador         object
# Periodo            int64
# DATA             float64
# dtype: object
# Proporción de nulos en df_gasto_via_acceso: 0.00%
#
# Cargando y verificando df_gasto_alojamiento...
# Primeras filas del archivo larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/2-Gasto de los turistas internacionales según alojamiento principal.csv:
#   Tipo de alojamiento    Indicador  Periodo       DATA
# 0               TOTAL  Gasto total     2016   93087.88
# 1               TOTAL  Gasto total     2017  101962.17
# 2               TOTAL  Gasto total     2018  101126.50
# 3               TOTAL  Gasto total     2019   98201.73
# 4               TOTAL  Gasto total     2020   21835.28
#
# Valores nulos por columna en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/2-Gasto de los turistas internacionales según alojamiento principal.csv:
# Tipo de alojamiento    0
# Indicador              0
# Periodo                0
# DATA                   0
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/2-Gasto de los turistas internacionales según alojamiento principal.csv:
# Tipo de alojamiento     object
# Indicador               object
# Periodo                  int64
# DATA                   float64
# dtype: object
# Proporción de nulos en df_gasto_alojamiento: 0.00%
#
# Cargando y verificando df_gasto_motivo_viaje...
# Primeras filas del archivo larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/3-Gasto de los turistas internacionales según motivo principal del viaje.csv:
#   Motivo del viaje    Indicador  Periodo       DATA
# 0            TOTAL  Gasto total     2016   93087.88
# 1            TOTAL  Gasto total     2017  101962.17
# 2            TOTAL  Gasto total     2018  101126.50
# 3            TOTAL  Gasto total     2019   98201.73
# 4            TOTAL  Gasto total     2020   21835.28
#
# Valores nulos por columna en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/3-Gasto de los turistas internacionales según motivo principal del viaje.csv:
# Motivo del viaje    0
# Indicador           0
# Periodo             0
# DATA                0
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/3-Gasto de los turistas internacionales según motivo principal del viaje.csv:
# Motivo del viaje     object
# Indicador            object
# Periodo               int64
# DATA                float64
# dtype: object
# Proporción de nulos en df_gasto_motivo_viaje: 0.00%
#
# Cargando y verificando df_gasto_pais_residencia...
# Primeras filas del archivo larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/4-Gasto de los turistas internacionales según país de residencia.csv:
#   País de residencia    Indicador  Periodo       DATA
# 0              TOTAL  Gasto total     2016   93087.88
# 1              TOTAL  Gasto total     2017  101962.17
# 2              TOTAL  Gasto total     2018  101126.50
# 3              TOTAL  Gasto total     2019   98201.73
# 4              TOTAL  Gasto total     2020   21835.28
#
# Valores nulos por columna en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/4-Gasto de los turistas internacionales según país de residencia.csv:
# País de residencia    0
# Indicador             0
# Periodo               0
# DATA                  0
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/4-Gasto de los turistas internacionales según país de residencia.csv:
# País de residencia     object
# Indicador              object
# Periodo                 int64
# DATA                  float64
# dtype: object
# Proporción de nulos en df_gasto_pais_residencia: 0.00%
#
# Cargando y verificando df_gasto_organizacion_viaje...
# Primeras filas del archivo larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/5-Gasto de los turistas internacionales según forma organización del viaje.csv:
#   Forma de organización del viaje    Indicador  Periodo       DATA
# 0                           TOTAL  Gasto total     2016   93087.88
# 1                           TOTAL  Gasto total     2017  101962.17
# 2                           TOTAL  Gasto total     2018  101126.50
# 3                           TOTAL  Gasto total     2019   98201.73
# 4                           TOTAL  Gasto total     2020   21835.28
#
# Valores nulos por columna en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/5-Gasto de los turistas internacionales según forma organización del viaje.csv:
# Forma de organización del viaje    0
# Indicador                          0
# Periodo                            0
# DATA                               4
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/5-Gasto de los turistas internacionales según forma organización del viaje.csv:
# Forma de organización del viaje     object
# Indicador                           object
# Periodo                              int64
# DATA                               float64
# dtype: object
# Proporción de nulos en df_gasto_organizacion_viaje: 1.04%
#
# Cargando y verificando df_gasto_duracion_viaje...
# Primeras filas del archivo larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/6-Gasto de los turistas internacionales según duración del viaje.csv:
#   Duración del viaje    Indicador  Periodo       DATA
# 0              TOTAL  Gasto total     2016   93087.88
# 1              TOTAL  Gasto total     2017  101962.17
# 2              TOTAL  Gasto total     2018  101126.50
# 3              TOTAL  Gasto total     2019   98201.73
# 4              TOTAL  Gasto total     2020   21835.28
#
# Valores nulos por columna en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/6-Gasto de los turistas internacionales según duración del viaje.csv:
# Duración del viaje    0
# Indicador             0
# Periodo               0
# DATA                  0
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/6-Gasto de los turistas internacionales según duración del viaje.csv:
# Duración del viaje     object
# Indicador              object
# Periodo                 int64
# DATA                  float64
# dtype: object
# Proporción de nulos en df_gasto_duracion_viaje: 0.00%
#
# Cargando y verificando df_gasto_partidas...
# Primeras filas del archivo larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/7-Gasto de los turistas internacionales según partidas de gasto.csv:
#   Tipo de gasto  Periodo       DATA
# 0         TOTAL     2016   93087.88
# 1         TOTAL     2017  101962.17
# 2         TOTAL     2018  101126.50
# 3         TOTAL     2019   98201.73
# 4         TOTAL     2020   21835.28
#
# Valores nulos por columna en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/7-Gasto de los turistas internacionales según partidas de gasto.csv:
# Tipo de gasto    0
# Periodo          0
# DATA             0
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/7-Gasto de los turistas internacionales según partidas de gasto.csv:
# Tipo de gasto     object
# Periodo            int64
# DATA             float64
# dtype: object
# Proporción de nulos en df_gasto_partidas: 0.00%
#
# Cargando y verificando df_turistas_via_acceso...
# Primeras filas del archivo larioja.org/Turismo/Encuestas turísticas/Estadística de Movimientos Turísticos en Fronteras para La Rioja/1-Número de turistas según via de acceso principal.csv:
#   Via de acceso  Periodo      DATA
# 0         TOTAL     2016  150778.8
# 1         TOTAL     2017  124188.8
# 2         TOTAL     2018  142926.4
# 3         TOTAL     2019  139497.3
# 4         TOTAL     2020   45355.2
#
# Valores nulos por columna en larioja.org/Turismo/Encuestas turísticas/Estadística de Movimientos Turísticos en Fronteras para La Rioja/1-Número de turistas según via de acceso principal.csv:
# Via de acceso    0
# Periodo          0
# DATA             0
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Encuestas turísticas/Estadística de Movimientos Turísticos en Fronteras para La Rioja/1-Número de turistas según via de acceso principal.csv:
# Via de acceso     object
# Periodo            int64
# DATA             float64
# dtype: object
# Proporción de nulos en df_turistas_via_acceso: 0.00%
#
# Cargando y verificando df_turistas_alojamiento...
# Primeras filas del archivo larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/2-Gasto de los turistas internacionales según alojamiento principal.csv:
#   Tipo de alojamiento    Indicador  Periodo       DATA
# 0               TOTAL  Gasto total     2016   93087.88
# 1               TOTAL  Gasto total     2017  101962.17
# 2               TOTAL  Gasto total     2018  101126.50
# 3               TOTAL  Gasto total     2019   98201.73
# 4               TOTAL  Gasto total     2020   21835.28
#
# Valores nulos por columna en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/2-Gasto de los turistas internacionales según alojamiento principal.csv:
# Tipo de alojamiento    0
# Indicador              0
# Periodo                0
# DATA                   0
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/2-Gasto de los turistas internacionales según alojamiento principal.csv:
# Tipo de alojamiento     object
# Indicador               object
# Periodo                  int64
# DATA                   float64
# dtype: object
# Proporción de nulos en df_turistas_alojamiento: 0.00%
#
# Cargando y verificando df_turistas_motivo_viaje...
# Primeras filas del archivo larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/3-Gasto de los turistas internacionales según motivo principal del viaje.csv:
#   Motivo del viaje    Indicador  Periodo       DATA
# 0            TOTAL  Gasto total     2016   93087.88
# 1            TOTAL  Gasto total     2017  101962.17
# 2            TOTAL  Gasto total     2018  101126.50
# 3            TOTAL  Gasto total     2019   98201.73
# 4            TOTAL  Gasto total     2020   21835.28
#
# Valores nulos por columna en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/3-Gasto de los turistas internacionales según motivo principal del viaje.csv:
# Motivo del viaje    0
# Indicador           0
# Periodo             0
# DATA                0
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/3-Gasto de los turistas internacionales según motivo principal del viaje.csv:
# Motivo del viaje     object
# Indicador            object
# Periodo               int64
# DATA                float64
# dtype: object
# Proporción de nulos en df_turistas_motivo_viaje: 0.00%
#
# Cargando y verificando df_turistas_pais_residencia...
# Primeras filas del archivo larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/4-Gasto de los turistas internacionales según país de residencia.csv:
#   País de residencia    Indicador  Periodo       DATA
# 0              TOTAL  Gasto total     2016   93087.88
# 1              TOTAL  Gasto total     2017  101962.17
# 2              TOTAL  Gasto total     2018  101126.50
# 3              TOTAL  Gasto total     2019   98201.73
# 4              TOTAL  Gasto total     2020   21835.28
#
# Valores nulos por columna en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/4-Gasto de los turistas internacionales según país de residencia.csv:
# País de residencia    0
# Indicador             0
# Periodo               0
# DATA                  0
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/4-Gasto de los turistas internacionales según país de residencia.csv:
# País de residencia     object
# Indicador              object
# Periodo                 int64
# DATA                  float64
# dtype: object
# Proporción de nulos en df_turistas_pais_residencia: 0.00%
#
# Cargando y verificando df_turistas_organizacion_viaje...
# Primeras filas del archivo larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/5-Gasto de los turistas internacionales según forma organización del viaje.csv:
#   Forma de organización del viaje    Indicador  Periodo       DATA
# 0                           TOTAL  Gasto total     2016   93087.88
# 1                           TOTAL  Gasto total     2017  101962.17
# 2                           TOTAL  Gasto total     2018  101126.50
# 3                           TOTAL  Gasto total     2019   98201.73
# 4                           TOTAL  Gasto total     2020   21835.28
#
# Valores nulos por columna en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/5-Gasto de los turistas internacionales según forma organización del viaje.csv:
# Forma de organización del viaje    0
# Indicador                          0
# Periodo                            0
# DATA                               4
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/5-Gasto de los turistas internacionales según forma organización del viaje.csv:
# Forma de organización del viaje     object
# Indicador                           object
# Periodo                              int64
# DATA                               float64
# dtype: object
# Proporción de nulos en df_turistas_organizacion_viaje: 1.04%
#
# Cargando y verificando df_turistas_duracion_viaje...
# Primeras filas del archivo larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/6-Gasto de los turistas internacionales según duración del viaje.csv:
#   Duración del viaje    Indicador  Periodo       DATA
# 0              TOTAL  Gasto total     2016   93087.88
# 1              TOTAL  Gasto total     2017  101962.17
# 2              TOTAL  Gasto total     2018  101126.50
# 3              TOTAL  Gasto total     2019   98201.73
# 4              TOTAL  Gasto total     2020   21835.28
#
# Valores nulos por columna en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/6-Gasto de los turistas internacionales según duración del viaje.csv:
# Duración del viaje    0
# Indicador             0
# Periodo               0
# DATA                  0
# dtype: int64
#
# Tipos de datos en larioja.org/Turismo/Encuestas turísticas/Encuesta de Gasto Turístico en La Rioja/6-Gasto de los turistas internacionales según duración del viaje.csv:
# Duración del viaje     object
# Indicador              object
# Periodo                 int64
# DATA                  float64
# dtype: object
# Proporción de nulos en df_turistas_duracion_viaje: 0.00%

# %%
def limpiar_datos(df, columnas_fecha, columnas_float, metodo_imputacion):
    # Convertir columnas a formato de fecha si existen
    for columna in columnas_fecha:
        if columna in df.columns:
            df[columna] = pd.to_datetime(df[columna], format='%YM%m', errors='coerce')
    
    # Convertir columnas a float si existen
    for columna in columnas_float:
        if columna in df.columns:
            df[columna] = pd.to_numeric(df[columna], errors='coerce')
    
    # Imputar valores nulos en la columna 'DATA' según el método seleccionado
    if 'DATA' in df.columns:
        if metodo_imputacion == 'media':
            df['DATA'].fillna(df['DATA'].mean(), inplace=True)
        elif metodo_imputacion == 'mediana':
            df['DATA'].fillna(df['DATA'].median(), inplace=True)
        elif metodo_imputacion == 'moda':
            df['DATA'].fillna(df['DATA'].mode()[0], inplace=True)
    
    # Verificar si hay valores nulos después de la conversión
    print(f"\nValores nulos después de la conversión en {df.columns.tolist()}:")
    print(df.isnull().sum())
    
    return df

# Listado de DataFrames con sus métodos de imputación
dataframes_info = {
    "df_precio_hotelero": {"columnas_fecha": ["Periodo"], "columnas_float": ["DATA"], "metodo_imputacion": "mediana"},
    "df_adr_revpar": {"columnas_fecha": ["Periodo"], "columnas_float": ["DATA"], "metodo_imputacion": "media"},
    "df_ipap": {"columnas_fecha": ["Periodo"], "columnas_float": ["DATA"], "metodo_imputacion": "mediana"},
    "df_num_empresas": {"columnas_fecha": [], "columnas_float": ["DATA"], "metodo_imputacion": "mediana"},
    "df_afiliados_regimen": {"columnas_fecha": [], "columnas_float": ["DATA"], "metodo_imputacion": "mediana"},
    "df_establecimientos_turisticos": {"columnas_fecha": [], "columnas_float": ["DATA"], "metodo_imputacion": "mediana"},
    "df_hoteles_capacidad": {"columnas_fecha": [], "columnas_float": ["DATA"], "metodo_imputacion": "mediana"},
    "df_apartamentos_capacidad": {"columnas_fecha": [], "columnas_float": ["DATA"], "metodo_imputacion": "mediana"},
    "df_viviendas_uso_turistico": {"columnas_fecha": [], "columnas_float": ["DATA"], "metodo_imputacion": "mediana"},
    "df_campings_capacidad": {"columnas_fecha": [], "columnas_float": ["DATA"], "metodo_imputacion": "mediana"},
    "df_casas_rurales_capacidad": {"columnas_fecha": [], "columnas_float": ["DATA"], "metodo_imputacion": "mediana"},
    "df_plazas_por_habitante": {"columnas_fecha": [], "columnas_float": ["DATA"], "metodo_imputacion": "mediana"},
    "df_gasto_organizacion_viaje": {"columnas_fecha": [], "columnas_float": ["DATA"], "metodo_imputacion": "mediana"}
}

# Limpiar cada DataFrame con el método de imputación adecuado
for nombre_df, info in dataframes_info.items():
    print(f"\nLimpiando {nombre_df}...")
    dataframes[nombre_df] = limpiar_datos(dataframes[nombre_df], info['columnas_fecha'], info['columnas_float'], info['metodo_imputacion'])
# Out:
# Limpiando df_precio_hotelero...
#
# Valores nulos después de la conversión en ['Periodo', 'Categoría', 'DATA']:
# Periodo      0
# Categoría    0
# DATA         0
# dtype: int64
#
# Limpiando df_adr_revpar...
#
# Valores nulos después de la conversión en ['Periodo', 'Municipio', 'Indicador', 'Categoría', 'DATA']:
# Periodo      0
# Municipio    0
# Indicador    0
# Categoría    0
# DATA         0
# dtype: int64
#
# Limpiando df_ipap...
#
# Valores nulos después de la conversión en ['Periodo', 'Tarifa', 'Variable', 'DATA']:
# Periodo     0
# Tarifa      0
# Variable    0
# DATA        0
# dtype: int64
#
# Limpiando df_num_empresas...
#
# Valores nulos después de la conversión en ['Grupo actividad sector turístico', 'Indicador', 'Periodo', 'DATA']:
# Grupo actividad sector turístico    0
# Indicador                           0
# Periodo                             0
# DATA                                0
# dtype: int64
#
# Limpiando df_afiliados_regimen...
#
# Valores nulos después de la conversión en ['Grupo actividad sector turístico', 'Régimen de afiliación', 'Periodo', 'DATA']:
# Grupo actividad sector turístico    0
# Régimen de afiliación               0
# Periodo                             0
# DATA                                0
# dtype: int64
#
# Limpiando df_establecimientos_turisticos...
#
# Valores nulos después de la conversión en ['Municipio', 'Tipo de establecimiento', 'Indicador', 'Periodo', 'DATA']:
# Municipio                  0
# Tipo de establecimiento    0
# Indicador                  0
# Periodo                    0
# DATA                       0
# dtype: int64
#
# Limpiando df_hoteles_capacidad...
#
# Valores nulos después de la conversión en ['Municipio', 'Categoría turística', 'Indicador', 'Periodo', 'DATA']:
# Municipio              0
# Categoría turística    0
# Indicador              0
# Periodo                0
# DATA                   0
# dtype: int64
#
# Limpiando df_apartamentos_capacidad...
#
# Valores nulos después de la conversión en ['Municipio', 'Categoría turística', 'Indicador', 'Periodo', 'DATA']:
# Municipio              0
# Categoría turística    0
# Indicador              0
# Periodo                0
# DATA                   0
# dtype: int64
#
# Limpiando df_viviendas_uso_turistico...
#
# Valores nulos después de la conversión en ['Municipio', 'Tipo de establecimiento', 'Periodo', 'DATA']:
# Municipio                  0
# Tipo de establecimiento    0
# Periodo                    0
# DATA                       0
# dtype: int64
#
# Limpiando df_campings_capacidad...
#
# Valores nulos después de la conversión en ['Municipio', 'Categoría turística', 'Indicador', 'Periodo', 'DATA']:
# Municipio              0
# Categoría turística    0
# Indicador              0
# Periodo                0
# DATA                   0
# dtype: int64
#
# Limpiando df_casas_rurales_capacidad...
#
# Valores nulos después de la conversión en ['Municipio', 'Categoría turística', 'Indicador', 'Periodo', 'DATA']:
# Municipio              0
# Categoría turística    0
# Indicador              0
# Periodo                0
# DATA                   0
# dtype: int64
#
# Limpiando df_plazas_por_habitante...
#
# Valores nulos después de la conversión en ['Municipio', 'Indicador', 'Periodo', 'DATA']:
# Municipio    0
# Indicador    0
# Periodo      0
# DATA         0
# dtype: int64
#
# Limpiando df_gasto_organizacion_viaje...
#
# Valores nulos después de la conversión en ['Forma de organización del viaje', 'Indicador', 'Periodo', 'DATA']:
# Forma de organización del viaje    0
# Indicador                          0
# Periodo                            0
# DATA                               0
# dtype: int64

# %%
# Verificar la cantidad de filas y columnas de cada DataFrame individual
for nombre_df, df in dataframes.items():
    print(f"DataFrame {nombre_df}: {df.shape}")

# Mostrar algunas filas de cada DataFrame para verificar su contenido
for nombre_df, df in dataframes.items():
    print(f"\nPrimeras filas de {nombre_df}:")
    print(df.head())
# Out:
# DataFrame df_precio_hotelero: (665, 3)
# DataFrame df_adr_revpar: (6696, 5)
# DataFrame df_ipac: (192, 3)
# DataFrame df_ipap: (582, 4)
# DataFrame df_iptr: (582, 4)
# DataFrame df_num_empresas: (196, 4)
# DataFrame df_afiliados_regimen: (1505, 4)
# DataFrame df_afiliados_contrato: (1204, 4)
# DataFrame df_magnitudes_2015: (252, 4)
# DataFrame df_indicadores_2015: (378, 4)
# DataFrame df_personal_2015: (126, 4)
# DataFrame df_magnitudes_2008_2014: (245, 4)
# DataFrame df_indicadores_2008_2014: (196, 4)
# DataFrame df_personal_2008_2014: (147, 4)
# DataFrame df_establecimientos_turisticos: (67200, 5)
# DataFrame df_hoteles_capacidad: (50400, 5)
# DataFrame df_apartamentos_capacidad: (33600, 5)
# DataFrame df_viviendas_uso_turistico: (1225, 4)
# DataFrame df_campings_capacidad: (26250, 5)
# DataFrame df_casas_rurales_capacidad: (33600, 5)
# DataFrame df_plazas_por_habitante: (5600, 4)
# DataFrame df_gasto_via_acceso: (96, 4)
# DataFrame df_gasto_alojamiento: (96, 4)
# DataFrame df_gasto_motivo_viaje: (128, 4)
# DataFrame df_gasto_pais_residencia: (160, 4)
# DataFrame df_gasto_organizacion_viaje: (96, 4)
# DataFrame df_gasto_duracion_viaje: (96, 4)
# DataFrame df_gasto_partidas: (40, 3)
# DataFrame df_turistas_via_acceso: (24, 3)
# DataFrame df_turistas_alojamiento: (96, 4)
# DataFrame df_turistas_motivo_viaje: (128, 4)
# DataFrame df_turistas_pais_residencia: (160, 4)
# DataFrame df_turistas_organizacion_viaje: (96, 4)
# DataFrame df_turistas_duracion_viaje: (96, 4)
#
# Primeras filas de df_precio_hotelero:
#      Periodo                 Categoría   DATA
# 0 2016-01-01                     TOTAL  85.32
# 1 2016-01-01        4 estrellas de oro  90.27
# 2 2016-01-01        3 estrellas de oro  81.61
# 3 2016-01-01         1 estrella de oro  96.86
# 4 2016-01-01  2 y 3 estrellas de plata  66.79
#
# Primeras filas de df_adr_revpar:
#      Periodo Municipio                                          Indicador  \
# 0 2016-01-01  LA RIOJA  Facturación media por cada habitación ocupada ...
# 1 2016-01-01  LA RIOJA  Facturación media por cada habitación ocupada ...
# 2 2016-01-01  LA RIOJA  Facturación media por cada habitación ocupada ...
# 3 2016-01-01  LA RIOJA  Facturación media por cada habitación ocupada ...
# 4 2016-01-01  LA RIOJA  Facturación media por cada habitación ocupada ...
#
#               Categoría   DATA
# 0                 TOTAL  56.87
# 1    4 estrellas de oro  77.26
# 2    3 estrellas de oro  51.87
# 3    2 estrellas de oro  42.25
# 4  2 estrellas de plata  47.06
#
# Primeras filas de df_ipac:
#    Periodo       Variable    DATA
# 0  2016M01         Índice  217.98
# 1  2016M01  Var (%) anual    1.64
# 2  2016M02         Índice  207.84
# 3  2016M02  Var (%) anual   -1.40
# 4  2016M03         Índice  143.65
#
# Primeras filas de df_ipap:
#      Periodo         Tarifa       Variable     DATA
# 0 2016-01-01          TOTAL         Índice  123.810
# 1 2016-01-01          TOTAL  Var (%) anual    7.710
# 2 2016-01-01         Normal         Índice   68.315
# 3 2016-01-01         Normal  Var (%) anual   68.315
# 4 2016-01-01  Fin de semana         Índice   68.315
#
# Primeras filas de df_iptr:
#    Periodo         Tarifa       Variable    DATA
# 0  2016M01          TOTAL         Índice  150.89
# 1  2016M01          TOTAL  Var (%) anual    2.06
# 2  2016M01         Normal         Índice  147.67
# 3  2016M01         Normal  Var (%) anual    3.17
# 4  2016M01  Fin de semana         Índice  150.13
#
# Primeras filas de df_num_empresas:
#   Grupo actividad sector turístico           Indicador  Periodo     DATA
# 0           TOTAL SECTOR SERVICIOS  Número de empresas     2008  16501.0
# 1           TOTAL SECTOR SERVICIOS  Número de empresas     2009  16522.0
# 2           TOTAL SECTOR SERVICIOS  Número de empresas     2010  16666.0
# 3           TOTAL SECTOR SERVICIOS  Número de empresas     2011  16614.0
# 4           TOTAL SECTOR SERVICIOS  Número de empresas     2012  16508.0
#
# Primeras filas de df_afiliados_regimen:
#   Grupo actividad sector turístico Régimen de afiliación Periodo     DATA
# 0           TOTAL SECTOR SERVICIOS                 TOTAL  2011T2  74739.0
# 1           TOTAL SECTOR SERVICIOS                 TOTAL  2011T3  74384.0
# 2           TOTAL SECTOR SERVICIOS                 TOTAL  2011T4  73681.0
# 3           TOTAL SECTOR SERVICIOS                 TOTAL  2012T1  73363.0
# 4           TOTAL SECTOR SERVICIOS                 TOTAL  2012T2  73885.0
#
# Primeras filas de df_afiliados_contrato:
#   Grupo actividad sector turístico Tipo de contrato Periodo   DATA
# 0           TOTAL SECTOR SERVICIOS            TOTAL  2011T2  74739
# 1           TOTAL SECTOR SERVICIOS            TOTAL  2011T3  74384
# 2           TOTAL SECTOR SERVICIOS            TOTAL  2011T4  73681
# 3           TOTAL SECTOR SERVICIOS            TOTAL  2012T1  73363
# 4           TOTAL SECTOR SERVICIOS            TOTAL  2012T2  73885
#
# Primeras filas de df_magnitudes_2015:
#   Grupo actividad sector turístico             Indicador  Periodo         DATA
# 0           TOTAL SECTOR SERVICIOS  Consumos Intermedios     2015   912114.465
# 1           TOTAL SECTOR SERVICIOS  Consumos Intermedios     2016   964596.809
# 2           TOTAL SECTOR SERVICIOS  Consumos Intermedios     2017   998496.867
# 3           TOTAL SECTOR SERVICIOS  Consumos Intermedios     2018  1088201.830
# 4           TOTAL SECTOR SERVICIOS  Consumos Intermedios     2019  1134462.299
#
# Primeras filas de df_indicadores_2015:
#   Grupo actividad sector turístico      Indicador  Periodo       DATA
# 0           TOTAL SECTOR SERVICIOS  Salario medio     2015  19892.923
# 1           TOTAL SECTOR SERVICIOS  Salario medio     2016  19070.827
# 2           TOTAL SECTOR SERVICIOS  Salario medio     2017  19229.551
# 3           TOTAL SECTOR SERVICIOS  Salario medio     2018  20211.762
# 4           TOTAL SECTOR SERVICIOS  Salario medio     2019  21067.722
#
# Primeras filas de df_personal_2015:
#   Grupo actividad sector turístico               Indicador  Periodo       DATA
# 0           TOTAL SECTOR SERVICIOS  Personal no remunerado     2015  11672.532
# 1           TOTAL SECTOR SERVICIOS  Personal no remunerado     2016  13379.933
# 2           TOTAL SECTOR SERVICIOS  Personal no remunerado     2017  12161.933
# 3           TOTAL SECTOR SERVICIOS  Personal no remunerado     2018  11939.725
# 4           TOTAL SECTOR SERVICIOS  Personal no remunerado     2019  11646.349
#
# Primeras filas de df_magnitudes_2008_2014:
#   Grupo actividad sector turístico  \
# 0           TOTAL SECTOR SERVICIOS
# 1           TOTAL SECTOR SERVICIOS
# 2           TOTAL SECTOR SERVICIOS
# 3           TOTAL SECTOR SERVICIOS
# 4           TOTAL SECTOR SERVICIOS
#
#                                          Indicador  Periodo        DATA
# 0  Excedente bruto de explotación (miles de euros)     2008  721640.388
# 1  Excedente bruto de explotación (miles de euros)     2009  578728.125
# 2  Excedente bruto de explotación (miles de euros)     2010  612539.060
# 3  Excedente bruto de explotación (miles de euros)     2011  544651.389
# 4  Excedente bruto de explotación (miles de euros)     2012  467381.413
#
# Primeras filas de df_indicadores_2008_2014:
#   Grupo actividad sector turístico           Indicador  Periodo        DATA
# 0           TOTAL SECTOR SERVICIOS  Sueldos y salarios     2008  675273.907
# 1           TOTAL SECTOR SERVICIOS  Sueldos y salarios     2009  618180.322
# 2           TOTAL SECTOR SERVICIOS  Sueldos y salarios     2010  615968.456
# 3           TOTAL SECTOR SERVICIOS  Sueldos y salarios     2011  631114.561
# 4           TOTAL SECTOR SERVICIOS  Sueldos y salarios     2012  608698.047
#
# Primeras filas de df_personal_2008_2014:
#   Grupo actividad sector turístico               Indicador  Periodo       DATA
# 0           TOTAL SECTOR SERVICIOS  Personal no remunerado     2008  12887.719
# 1           TOTAL SECTOR SERVICIOS  Personal no remunerado     2009  12694.030
# 2           TOTAL SECTOR SERVICIOS  Personal no remunerado     2010  12335.670
# 3           TOTAL SECTOR SERVICIOS  Personal no remunerado     2011  11788.248
# 4           TOTAL SECTOR SERVICIOS  Personal no remunerado     2012  12100.205
#
# Primeras filas de df_establecimientos_turisticos:
#   Municipio Tipo de establecimiento         Indicador  Periodo  DATA
# 0  LA RIOJA                 Hoteles  Establecimientos     2009  63.0
# 1  LA RIOJA                 Hoteles  Establecimientos     2010  63.0
# 2  LA RIOJA                 Hoteles  Establecimientos     2011  63.0
# 3  LA RIOJA                 Hoteles  Establecimientos     2012  66.0
# 4  LA RIOJA                 Hoteles  Establecimientos     2013  70.0
#
# Primeras filas de df_hoteles_capacidad:
#   Municipio Categoría turística Indicador  Periodo    DATA
# 0  LA RIOJA               TOTAL    Plazas     2009  4613.0
# 1  LA RIOJA               TOTAL    Plazas     2010  4583.0
# 2  LA RIOJA               TOTAL    Plazas     2011  4583.0
# 3  LA RIOJA               TOTAL    Plazas     2012  4706.0
# 4  LA RIOJA               TOTAL    Plazas     2013  4713.0
#
# Primeras filas de df_apartamentos_capacidad:
#   Municipio Categoría turística         Indicador  Periodo  DATA
# 0  LA RIOJA               TOTAL  Establecimientos     2009  37.0
# 1  LA RIOJA               TOTAL  Establecimientos     2010  44.0
# 2  LA RIOJA               TOTAL  Establecimientos     2011  44.0
# 3  LA RIOJA               TOTAL  Establecimientos     2012  50.0
# 4  LA RIOJA               TOTAL  Establecimientos     2013  62.0
#
# Primeras filas de df_viviendas_uso_turistico:
#   Municipio     Tipo de establecimiento  Periodo    DATA
# 0  LA RIOJA  Viviendas de uso turístico     2018   480.0
# 1  LA RIOJA  Viviendas de uso turístico     2019   796.0
# 2  LA RIOJA  Viviendas de uso turístico     2020  1042.0
# 3  LA RIOJA  Viviendas de uso turístico     2021  1072.0
# 4  LA RIOJA  Viviendas de uso turístico     2022  1094.0
#
# Primeras filas de df_campings_capacidad:
#   Municipio Categoría turística Indicador  Periodo    DATA
# 0  LA RIOJA               TOTAL    Plazas     2009  6252.0
# 1  LA RIOJA               TOTAL    Plazas     2010  6252.0
# 2  LA RIOJA               TOTAL    Plazas     2011  6252.0
# 3  LA RIOJA               TOTAL    Plazas     2012  6252.0
# 4  LA RIOJA               TOTAL    Plazas     2013  6252.0
#
# Primeras filas de df_casas_rurales_capacidad:
#   Municipio Categoría turística         Indicador  Periodo   DATA
# 0  LA RIOJA               TOTAL  Establecimientos     2009  107.0
# 1  LA RIOJA               TOTAL  Establecimientos     2010  112.0
# 2  LA RIOJA               TOTAL  Establecimientos     2011  112.0
# 3  LA RIOJA               TOTAL  Establecimientos     2012  124.0
# 4  LA RIOJA               TOTAL  Establecimientos     2013  130.0
#
# Primeras filas de df_plazas_por_habitante:
#   Municipio       Indicador  Periodo     DATA
# 0  LA RIOJA  Plazas Totales     2009  14491.0
# 1  LA RIOJA  Plazas Totales     2010  14686.0
# 2  LA RIOJA  Plazas Totales     2011  14686.0
# 3  LA RIOJA  Plazas Totales     2012  15075.0
# 4  LA RIOJA  Plazas Totales     2013  15337.0
#
# Primeras filas de df_gasto_via_acceso:
#   Via de acceso    Indicador  Periodo       DATA
# 0         TOTAL  Gasto total     2016   93087.88
# 1         TOTAL  Gasto total     2017  101962.17
# 2         TOTAL  Gasto total     2018  101126.50
# 3         TOTAL  Gasto total     2019   98201.73
# 4         TOTAL  Gasto total     2020   21835.28
#
# Primeras filas de df_gasto_alojamiento:
#   Tipo de alojamiento    Indicador  Periodo       DATA
# 0               TOTAL  Gasto total     2016   93087.88
# 1               TOTAL  Gasto total     2017  101962.17
# 2               TOTAL  Gasto total     2018  101126.50
# 3               TOTAL  Gasto total     2019   98201.73
# 4               TOTAL  Gasto total     2020   21835.28
#
# Primeras filas de df_gasto_motivo_viaje:
#   Motivo del viaje    Indicador  Periodo       DATA
# 0            TOTAL  Gasto total     2016   93087.88
# 1            TOTAL  Gasto total     2017  101962.17
# 2            TOTAL  Gasto total     2018  101126.50
# 3            TOTAL  Gasto total     2019   98201.73
# 4            TOTAL  Gasto total     2020   21835.28
#
# Primeras filas de df_gasto_pais_residencia:
#   País de residencia    Indicador  Periodo       DATA
# 0              TOTAL  Gasto total     2016   93087.88
# 1              TOTAL  Gasto total     2017  101962.17
# 2              TOTAL  Gasto total     2018  101126.50
# 3              TOTAL  Gasto total     2019   98201.73
# 4              TOTAL  Gasto total     2020   21835.28
#
# Primeras filas de df_gasto_organizacion_viaje:
#   Forma de organización del viaje    Indicador  Periodo       DATA
# 0                           TOTAL  Gasto total     2016   93087.88
# 1                           TOTAL  Gasto total     2017  101962.17
# 2                           TOTAL  Gasto total     2018  101126.50
# 3                           TOTAL  Gasto total     2019   98201.73
# 4                           TOTAL  Gasto total     2020   21835.28
#
# Primeras filas de df_gasto_duracion_viaje:
#   Duración del viaje    Indicador  Periodo       DATA
# 0              TOTAL  Gasto total     2016   93087.88
# 1              TOTAL  Gasto total     2017  101962.17
# 2              TOTAL  Gasto total     2018  101126.50
# 3              TOTAL  Gasto total     2019   98201.73
# 4              TOTAL  Gasto total     2020   21835.28
#
# Primeras filas de df_gasto_partidas:
#   Tipo de gasto  Periodo       DATA
# 0         TOTAL     2016   93087.88
# 1         TOTAL     2017  101962.17
# 2         TOTAL     2018  101126.50
# 3         TOTAL     2019   98201.73
# 4         TOTAL     2020   21835.28
#
# Primeras filas de df_turistas_via_acceso:
#   Via de acceso  Periodo      DATA
# 0         TOTAL     2016  150778.8
# 1         TOTAL     2017  124188.8
# 2         TOTAL     2018  142926.4
# 3         TOTAL     2019  139497.3
# 4         TOTAL     2020   45355.2
#
# Primeras filas de df_turistas_alojamiento:
#   Tipo de alojamiento    Indicador  Periodo       DATA
# 0               TOTAL  Gasto total     2016   93087.88
# 1               TOTAL  Gasto total     2017  101962.17
# 2               TOTAL  Gasto total     2018  101126.50
# 3               TOTAL  Gasto total     2019   98201.73
# 4               TOTAL  Gasto total     2020   21835.28
#
# Primeras filas de df_turistas_motivo_viaje:
#   Motivo del viaje    Indicador  Periodo       DATA
# 0            TOTAL  Gasto total     2016   93087.88
# 1            TOTAL  Gasto total     2017  101962.17
# 2            TOTAL  Gasto total     2018  101126.50
# 3            TOTAL  Gasto total     2019   98201.73
# 4            TOTAL  Gasto total     2020   21835.28
#
# Primeras filas de df_turistas_pais_residencia:
#   País de residencia    Indicador  Periodo       DATA
# 0              TOTAL  Gasto total     2016   93087.88
# 1              TOTAL  Gasto total     2017  101962.17
# 2              TOTAL  Gasto total     2018  101126.50
# 3              TOTAL  Gasto total     2019   98201.73
# 4              TOTAL  Gasto total     2020   21835.28
#
# Primeras filas de df_turistas_organizacion_viaje:
#   Forma de organización del viaje    Indicador  Periodo       DATA
# 0                           TOTAL  Gasto total     2016   93087.88
# 1                           TOTAL  Gasto total     2017  101962.17
# 2                           TOTAL  Gasto total     2018  101126.50
# 3                           TOTAL  Gasto total     2019   98201.73
# 4                           TOTAL  Gasto total     2020   21835.28
#
# Primeras filas de df_turistas_duracion_viaje:
#   Duración del viaje    Indicador  Periodo       DATA
# 0              TOTAL  Gasto total     2016   93087.88
# 1              TOTAL  Gasto total     2017  101962.17
# 2              TOTAL  Gasto total     2018  101126.50
# 3              TOTAL  Gasto total     2019   98201.73
# 4              TOTAL  Gasto total     2020   21835.28

# %%
df_afiliados_contrato.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df_afiliados_contrato.head()
#
# NameError: name 'df_afiliados_contrato' is not defined

# %%
# Exportar cada DataFrame limpio a un archivo CSV
# for nombre_df, df in dataframes.items():
#     archivo_salida = f"{nombre_df}.csv"
#     df.to_csv(archivo_salida, index=False)
#     print(f"Archivo exportado exitosamente: {archivo_salida}")
# Out:
# Archivo exportado exitosamente: df_precio_hotelero.csv
# Archivo exportado exitosamente: df_adr_revpar.csv
# Archivo exportado exitosamente: df_ipac.csv
# Archivo exportado exitosamente: df_ipap.csv
# Archivo exportado exitosamente: df_iptr.csv
# Archivo exportado exitosamente: df_num_empresas.csv
# Archivo exportado exitosamente: df_afiliados_regimen.csv
# Archivo exportado exitosamente: df_afiliados_contrato.csv
# Archivo exportado exitosamente: df_magnitudes_2015.csv
# Archivo exportado exitosamente: df_indicadores_2015.csv
# Archivo exportado exitosamente: df_personal_2015.csv
# Archivo exportado exitosamente: df_magnitudes_2008_2014.csv
# Archivo exportado exitosamente: df_indicadores_2008_2014.csv
# Archivo exportado exitosamente: df_personal_2008_2014.csv
# Archivo exportado exitosamente: df_establecimientos_turisticos.csv
# Archivo exportado exitosamente: df_hoteles_capacidad.csv
# Archivo exportado exitosamente: df_apartamentos_capacidad.csv
# Archivo exportado exitosamente: df_viviendas_uso_turistico.csv
# Archivo exportado exitosamente: df_campings_capacidad.csv
# Archivo exportado exitosamente: df_casas_rurales_capacidad.csv
# Archivo exportado exitosamente: df_plazas_por_habitante.csv
# Archivo exportado exitosamente: df_gasto_via_acceso.csv
# Archivo exportado exitosamente: df_gasto_alojamiento.csv
# Archivo exportado exitosamente: df_gasto_motivo_viaje.csv
# Archivo exportado exitosamente: df_gasto_pais_residencia.csv
# Archivo exportado exitosamente: df_gasto_organizacion_viaje.csv
# Archivo exportado exitosamente: df_gasto_duracion_viaje.csv
# Archivo exportado exitosamente: df_gasto_partidas.csv
# Archivo exportado exitosamente: df_turistas_via_acceso.csv
# Archivo exportado exitosamente: df_turistas_alojamiento.csv
# Archivo exportado exitosamente: df_turistas_motivo_viaje.csv
# Archivo exportado exitosamente: df_turistas_pais_residencia.csv
# Archivo exportado exitosamente: df_turistas_organizacion_viaje.csv
# Archivo exportado exitosamente: df_turistas_duracion_viaje.csv
